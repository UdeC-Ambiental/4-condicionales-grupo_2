# %% [markdown]
# # 🧩 Reto 2 – pH
# **Objetivo:** clasificar pH y generar alerta química.
#
# **Datos:** `../data/muestras_calidad_agua.csv`

# %% [markdown]
# ### Pasos
# 1. Carga el CSV en `df`.
# 2. Extrae `sitio` y `pH`.
# 3. Crea `clasificacion_pH` con tres rangos.
# 4. Crea `alerta_quimica` (revisión si pH < 6.5 o pH > 8.5).
# 5. Filtra `df_alerta` y exporta `resultado_ph.csv`.
#
# > **Reto adicional:** promedio y desviación estándar.

# %%
# Escribe tu código aquí
import pandas as pd 
# paso 1 : Cargar el archivo CSV 
df = pd.read_csv("muestras_calidad_agua.csv")
# mostar las primeras filas 
df.head()
# Out:
#                           sitio   pH  oxigeno  temperatura
# 0                Río Subachoque  7.2      7.8         18.5
# 1   Quebrada Honda (Facatativá)  6.3      6.2         19.4
# 2          Río Botello (Madrid)  6.8      5.9         22.7
# 3  Afluente San José (El Rosal)  7.9      8.3         20.1
# 4                   Río Villeta  8.7      6.1         28.3

# %%
df_ph = df[["sitio", "pH"]]
df_ph
# Out:
#                            sitio   pH
# 0                 Río Subachoque  7.2
# 1    Quebrada Honda (Facatativá)  6.3
# 2           Río Botello (Madrid)  6.8
# 3   Afluente San José (El Rosal)  7.9
# 4                    Río Villeta  8.7
# 5  Quebrada Cune (San Francisco)  6.0
# 6            Río Tobia (Nocaima)  7.4
# 7       Quebrada Negra (La Vega)  7.6
# 8          Río Bahamón (Sasaima)  8.1
# 9        Río Guayuriba (La Mesa)  5.9

# %%
def clasificar_ph(valor):
    if valor < 6.5:
        return "Ácido"
    elif valor <= 8.5:
        return "Neutro"
    else:
        return "Básico"

df_ph.loc[:, "clasificacion_pH"] = df_ph["pH"].apply(clasificar_ph)
df_ph
# Out:
#                            sitio   pH clasificacion_pH
# 0                 Río Subachoque  7.2           Neutro
# 1    Quebrada Honda (Facatativá)  6.3            Ácido
# 2           Río Botello (Madrid)  6.8           Neutro
# 3   Afluente San José (El Rosal)  7.9           Neutro
# 4                    Río Villeta  8.7           Básico
# 5  Quebrada Cune (San Francisco)  6.0            Ácido
# 6            Río Tobia (Nocaima)  7.4           Neutro
# 7       Quebrada Negra (La Vega)  7.6           Neutro
# 8          Río Bahamón (Sasaima)  8.1           Neutro
# 9        Río Guayuriba (La Mesa)  5.9            Ácido

# %%
df_ph["alerta_quimica"] = df_ph["pH"].apply(lambda x: "Alerta" if (x < 6.5 or x > 8.5) else "Normal")
df_ph
# Out:
#                            sitio   pH clasificacion_pH alerta_quimica
# 0                 Río Subachoque  7.2           Neutro         Normal
# 1    Quebrada Honda (Facatativá)  6.3            Ácido         Alerta
# 2           Río Botello (Madrid)  6.8           Neutro         Normal
# 3   Afluente San José (El Rosal)  7.9           Neutro         Normal
# 4                    Río Villeta  8.7           Básico         Alerta
# 5  Quebrada Cune (San Francisco)  6.0            Ácido         Alerta
# 6            Río Tobia (Nocaima)  7.4           Neutro         Normal
# 7       Quebrada Negra (La Vega)  7.6           Neutro         Normal
# 8          Río Bahamón (Sasaima)  8.1           Neutro         Normal
# 9        Río Guayuriba (La Mesa)  5.9            Ácido         Alerta

# %%
# Filtrar las muestras con alerta
df_alerta = df_ph[df_ph["alerta_quimica"] == "Revisar"]

# Mostrar el DataFrame filtrado
df_alerta
# Out:
# Empty DataFrame
# Columns: [sitio, pH, clasificacion_pH, alerta_quimica]
# Index: []

# %%
# Exportar el resultado a un CSV
df_alerta.to_csv("resultado_pH.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 # Exportar el resultado a un CSV
# ----> 2 df_alerta.to_csv("resultado_pH.csv", index=False)
#
# NameError: name 'df_alerta' is not defined

# %%
import os

print("Carpeta de trabajo (cwd):", os.getcwd())
print("\nArchivos en la carpeta actual:")
for f in os.listdir():
    print(" -", f)
    
# Si tu CSV está en una subcarpeta 'data', lista esa carpeta también
if os.path.isdir("data"):
    print("\nArchivos en ./data:")
    for f in os.listdir("data"):
        print(" -", f)
# Out:
# Carpeta de trabajo (cwd): C:\Users\User
#
# Archivos en la carpeta actual:
#  - .anaconda
#  - .conda
#  - .condarc
#  - .continuum
#  - .dotnet
#  - .ipynb_checkpoints
#  - .ipython
#  - .jupyter
#  - .ms-ad
#  - 3D Objects
#  - anaconda3
#  - anaconda_projects
#  - AppData
#  - Configuración local
#  - Contacts
#  - Cookies
#  - Datos de programa
#  - Documents
#  - Downloads
#  - Entorno de red
#  - Favorites
#  - Impresoras
#  - IntelGraphicsProfiles
#  - Links
#  - Menú Inicio
#  - Mis documentos
#  - muestras_calidad_agua.csv
#  - Music
#  - NTUSER.DAT
#  - ntuser.dat.LOG1
#  - ntuser.dat.LOG2
#  - NTUSER.DAT{2ad838bc-efea-11ee-a54d-000d3a94eaa1}.TM.blf
#  - NTUSER.DAT{2ad838bc-efea-11ee-a54d-000d3a94eaa1}.TMContainer00000000000000000001.regtrans-ms
#  - NTUSER.DAT{2ad838bc-efea-11ee-a54d-000d3a94eaa1}.TMContainer00000000000000000002.regtrans-ms
#  - ntuser.ini
#  - OneDrive
#  - Plantillas
#  - Reciente
#  - resultado_pH.csv
#  - reto2_ph.ipynb
#  - Saved Games
#  - Searches
# ...

# %%
import pandas as pd
df = pd.read_csv("muestras_calidad_agua.csv")
df.head()
# Out:
#                           sitio   pH  oxigeno  temperatura
# 0                Río Subachoque  7.2      7.8         18.5
# 1   Quebrada Honda (Facatativá)  6.3      6.2         19.4
# 2          Río Botello (Madrid)  6.8      5.9         22.7
# 3  Afluente San José (El Rosal)  7.9      8.3         20.1
# 4                   Río Villeta  8.7      6.1         28.3

# %%
# Extraer solo sitio y pH
df_ph = df[["sitio", "pH"]].copy()
df_ph.head()
# Out:
#                           sitio   pH
# 0                Río Subachoque  7.2
# 1   Quebrada Honda (Facatativá)  6.3
# 2          Río Botello (Madrid)  6.8
# 3  Afluente San José (El Rosal)  7.9
# 4                   Río Villeta  8.7

# %%
# Definir función de clasificación
def clasificar_ph(valor):
    if valor < 6.5:
        return "Ácido"
    elif valor <= 8.5:
        return "Neutro"
    else:
        return "Básico"

# Asignar columna usando .loc para evitar SettingWithCopyWarning
df_ph.loc[:, "clasificacion_pH"] = df_ph["pH"].apply(clasificar_ph)
df_ph.head()
# Out:
#                           sitio   pH clasificacion_pH
# 0                Río Subachoque  7.2           Neutro
# 1   Quebrada Honda (Facatativá)  6.3            Ácido
# 2          Río Botello (Madrid)  6.8           Neutro
# 3  Afluente San José (El Rosal)  7.9           Neutro
# 4                   Río Villeta  8.7           Básico

# %%
# Crear columna de alerta química
df_ph.loc[:, "alerta_quimica"] = df_ph["pH"].apply(lambda x: "Revisar" if (x < 6.5 or x > 8.5) else "Normal")

# Filtrar las muestras con alerta
df_alerta = df_ph[df_ph["alerta_quimica"] == "Revisar"]

# Mostrar las alertas (si hay)
display(df_alerta)

# Exportar a CSV solo si hay filas
if not df_alerta.empty:
    df_alerta.to_csv("resultado_ph.csv", index=False)
    print("✅ Archivo 'resultado_ph.csv' guardado correctamente.")
else:
    print("ℹ️ No hay filas en alerta (df_alerta está vacío). No se creó 'resultado_ph.csv'.")
# Out:
#                            sitio   pH clasificacion_pH alerta_quimica
# 1    Quebrada Honda (Facatativá)  6.3            Ácido        Revisar
# 4                    Río Villeta  8.7           Básico        Revisar
# 5  Quebrada Cune (San Francisco)  6.0            Ácido        Revisar
# 9        Río Guayuriba (La Mesa)  5.9            Ácido        Revisar
# ✅ Archivo 'resultado_ph.csv' guardado correctamente.
